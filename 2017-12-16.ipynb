# %% [markdown]
# ## 2017-12-18 Axel (1060)
# python3 src/run_train.py --train annotated_images --label_names annotated_images/_labels.txt --iteration 5000 --val_iteration 100 --loaderjob 4 --batchsize ? --log_iteration 100 --gpu 0

# %%
# %run src/visualize_bb.py testing_images/set1/ft2.jpg --pretrained_model ../results/2017-12-18_model300_5000_fragezeichen/model_iter_5000 --label_names ../results/2017-12-18_model300_5000_fragezeichen/_labels.txt
# Out:
# ([array([[ -21.99103355,  261.0637207 ,  647.4887085 ,  348.2074585 ]], dtype=float32)], [array([2])], [array([ 0.98690885], dtype=float32)])

# %%
# %run src/visualize_bb.py testing_images/set1/rh1.jpg --pretrained_model ../results/2017-12-18_model300_5000_fragezeichen/model_iter_5000 --label_names ../results/2017-12-18_model300_5000_fragezeichen/_labels.txt
# Out:
# ([array([[  16.67025948,   23.63840294,  479.81787109,  534.62475586],
#        [ 379.1958313 ,  553.21459961,  467.32070923,  640.9642334 ]], dtype=float32)], [array([5, 7])], [array([ 0.96570259,  0.58321267], dtype=float32)])

# %%
# %run src/visualize_bb.py testing_images/skyline.png --pretrained_model ../results/2017-12-18_model300_5000_fragezeichen/model_iter_5000 --label_names ../results/2017-12-18_model300_5000_fragezeichen/_labels.txt
# Out:
# ([array([[   50.82795334,   629.4152832 ,   486.05032349,   681.23260498],
#        [  431.62225342,  1096.7253418 ,   645.23748779,  1288.89074707],
#        [  445.06930542,   495.92095947,   651.34222412,   692.5390625 ],
#        [  362.76531982,    44.73542023,   526.23138428,   319.48791504],
#        [  326.37759399,   381.11264038,   476.29229736,   466.23855591],
#        [  567.7197876 ,   108.45085907,   819.9362793 ,   397.6975708 ],
#        [  396.38781738,   436.3973999 ,   610.7868042 ,   620.80072021],
#        [  559.29705811,   185.47782898,   773.9342041 ,   550.80072021],
#        [  397.06610107,   259.14822388,   507.16607666,   374.56634521],
#        [  493.38098145,   536.03808594,   672.90826416,   871.0378418 ],
#        [  403.92477417,   552.76708984,   621.57159424,   752.79309082]], dtype=float32)], [array([2, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7])], [array([ 0.50195432,  0.44037649,  0.3933132 ,  0.37348381,  0.35450017,
# ...
