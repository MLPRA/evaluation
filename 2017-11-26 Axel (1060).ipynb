# %% [markdown]
# ## 2017-11-26 Axel (1060)
# %run src/run_train.py --train annotated_images --label_names annotated_images/_labels.json --iteration 10000 --val_iteration 1000 --loaderjob 4 --batchsize 7 --log_iteration 10 --gpu 0

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %run src/visualize_bb.py testing_images/set1/ss1.jpg --pretrained_model ../backup/2017-11-26_model/model_iter_1000 --label_names ../backup/2017-11-26_model/_labels.txt
# Out:
# ([array([], shape=(0, 4), dtype=float32)], [array([], dtype=int32)], [array([], dtype=float32)])
# c:\repo\chainercv\chainercv\links\model\ssd\multibox_coder.py:238: RuntimeWarning: overflow encountered in exp
#   mb_score = xp.exp(mb_conf)
# c:\repo\chainercv\chainercv\links\model\ssd\multibox_coder.py:239: RuntimeWarning: invalid value encountered in true_divide
#   mb_score /= mb_score.sum(axis=1, keepdims=True)
# c:\repo\chainercv\chainercv\links\model\ssd\multibox_coder.py:249: RuntimeWarning: invalid value encountered in greater_equal
#   mask = score_l >= score_thresh

# %%
# Out:
#   File "<ipython-input-33-42ca2e617fcf>", line 2
#     5.42752504e-01  -1.09800279e+00]
#                  ^
# SyntaxError: invalid syntax
